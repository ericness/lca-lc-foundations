# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or permanent population, so it has no capital. If you want a fictional option, people sometimes invent names like “Lunapolis” or “Selene City” for stories. Want a playful idea for a sci‑fi setting?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 386, 'prompt_tokens': 13, 'total_tokens': 399, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7Tg6zehIuy3o3NYYOKar8ZYgOPTv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4470-7fc5-7801-8190-b5b6c8ea1c5e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 386, 'total_tokens': 399, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or permanent population, so it has no capital. If you want a fictional option, people sometimes invent names like “Lunapolis” or “Selene City” for stories. Want a playful idea for a sci‑fi setting?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-D7Tg6zehIuy3o3NYYOKar8ZYgOPTv',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 386,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 320,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 399}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0,
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. (If you’re joking or writing fiction, you could invent a city name like “Lunapolis.”)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='2b7098db-4632-4ea4-ba00-cfb7074286d1'),
#               AIMessage(content='There isn’t one. The Moon has no government or inhabitants, so it has no capital. If you’re thinking of a fictional setting, you could invent a capital city (e.g., Lunagrad or Selene City) and build a backstory around it—want help with a sci‑fi world-building idea?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 777, 'prompt_tokens': 13, 'total_tokens': 790, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7TiKv12TWIvs0PGLWFQFKMqmwSPP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c4472-9cb1-7c73-8f9e-f380f1d01995-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 777, 'total_tokens': 790, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})]}

# %%
print(response["messages"][-1].content)
# Out:
# There isn’t one. The Moon has no government or inhabitants, so it has no capital. If you’re thinking of a fictional setting, you could invent a capital city (e.g., Lunagrad or Selene City) and build a backstory around it—want help with a sci‑fi world-building idea?

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {
        "messages": [
            HumanMessage(content="What's the capital of the Moon?"),
            AIMessage(content="The capital of the Moon is Luna City."),
            HumanMessage(content="Interesting, tell me more about Luna City"),
        ]
    }
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='1de7552d-326c-47df-97c6-dc0ba9f0e8df'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='fd9d5fbb-029d-41a4-b9ec-7ae81d9cf9dd', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='226ddce0-5c1e-4772-8cdf-33485e8ac4fe'),
#               AIMessage(content='Luna City is fictional. There’s no real capital of the Moon, but here’s a fleshed-out concept you can use for a story, game, or world-building.\n\nSnapshot\n- A bustling lunar capital built inside a network of lava tubes and crater rims near the Moon’s south pole. It’s home to several million residents and acts as the political, economic, and cultural heart of a loose Lunar Federation (or Lunar Commonwealth, depending on your setting).\n\nSetting and design\n- Location: A protected enclave near the pole, chosen for access to constant sunlight on some rim elevations and hidden ice in shadowed regions. Structures are a mix of pressurized domes, reinforced lava-tube habitats, and solar canopies.\n- Architecture: Shielded, modular habitats with regolith shielding. Interiors emphasize open daylight-like illumination from artificial suns and bioluminescent flora in domed parks. Transit tubes and magnetic rails run through the lava tubes to minimize surface dust exposure.\n\nGovernment and society\n- Governance: A bicameral system with a Lunar Assembly (district representatives) and a City Council (executive branch). A Chancellor or Mayor chairs weekly sessions, with a rotating chair for emergency governance.\n- Population vibe: A diverse mix of Earth-born settlers and Moon-born residents who’ve grown up in low gravity. Culture blends Earth traditions with lunar-influenced rituals (e.g., “sunrise ceremonies” on peak canopies, regolith art made with ultra-fine dust).\n- Law and order: Civilian courts, a Space Police division, and a robust life-support regulatory body. Privacy is valued, but data and environmental telemetry are central to everyday life.\n\nDistricts and landmarks\n- The Crater Gate District: Logistics hubs, ore and ice processing facilities, and manufacturing. Dense transit corridors connect to the outside and to the markets.\n- The Atrium Quarter: Cultural center with museums, theaters, multimedia archives, and a large holo-market where residents shop and socialize.\n- Helios Dome District: Research and development zone with labs for materials science, life-support tech, and ISRU (in-situ resource utilization) experiments.\n- Artemis Heights: Residential rings and vertical farms, with schools, clinics, and community centers.\n- Icewell Market: Specialized district near the edges of shadowed craters for water ice storage, processing, and hydroponics supply chains.\n- Landmarks: Luna Gate (a ceremonial entrance), The Crystal Spire (long-range communications and orbital relay hub), Echo Archives (data vaults and encrypted records), and the Solar Crescent Array (a hybrid solar/nuclear energy complex).\n\nEconomy and technology\n- Energy: Solar arrays on crater rims with modular nuclear backups. Stored energy powers life support, transit, and industry.\n- Industry: 3D-printed habitats, regolith mining and processing, ISRU-based manufacturing, closed-loop agriculture, advanced life-support systems, and aerospace maintenance.\n- Currency and trade: A digital credit system used across lunar settlements and Earth orbital stations. Trade with Earth and visiting ships brings in essential supplies, high-grade alloys, and scientific equipment.\n- Daily tech: Personal exosuits for surface work, 1/6 g treadmills and microgravity exercise spaces, airlocks with automated decontamination, and water recycling plants.\n\nLife and culture\n- Daily life: Most people commute through pressurized transit tubes or magnetic rails. Greenhouses provide fresh produce; lunar gravity makes aging plants and seeds a careful balance of light and nutrients.\n- Education and science: Strong STEM focus, with schools linked to Helios Dome labs. Public curiosity about lunar geology, ice science, and space engineering is celebrated in festivals and exhibitions.\n- Challenges in daily life: Dust management, radiation exposure risk during solar storms, and dependence on Earth for certain supplies. Communities emphasize mutual a ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {
        "messages": [
            HumanMessage(content="Tell me all about Luna City, the capital of the Moon")
        ]
    },
    stream_mode="messages",
):
    # token is a message chunk with token content
    # metadata contains which node produced the token

    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional concept: a fully realized capital city on the Moon. Since there’s no real “Luna City” today, I’ll give you a thorough, self-contained profile you can use for world-building in stories, games, or games master notes. If you’ve got a specific vibe in mind (hard sci-fi, optimistic future, pulp adventure, etc.), tell me and I’ll tailor it.
#
# Core idea
# - Name: Luna City
# - Role: Capital of the Moon (the political, cultural, and scientific hub of the lunar polity)
# - Tone: High-tech, resilient, and cosmopolitan; a beacon of human presence on the Moon, balancing governance, science, industry, and culture in a challenging environment.
#
# What it is like now (summary)
# - Population: Roughly 2–5 million residents, a mix of lunar-born colonists, long-term Earth expatriates, scientists, engineers, and civil servants.
# - Government: A democratic-lederal system jointly run by a Lunar Assembly and an Executive Council; a professional civil service and a rotating lunar ambassadorial corps to Earth. In fiction, this can be a stable federation or a fragile coalition depending on the plot.
# - Economy: A diversified, resource-informed economy—water/ice mining, helium-3 and other lunar volatiles, solar energy production, high-precision manufacturing in microgravity, research and education, spaceport services, and a growing lunar tourism sector.
# - Culture: A melting pot of Earth cultures adapted to lunar life; festivals around solar events, strong emphasis on science literacy, arts inspired by Earth and Moonlight, and a distinctive lunar cuisine that uses algae, regolith minerals, and hydroponic greens.
# - Environment: Harsh but manageable—no breathable atmosphere, extreme temperature swings, radiation exposure, and pervasive lunar dust. The city lives inside and around shielded caverns, domed habitats, and crater rims with artificial climate control.
#
# Location and layout (concept)
# - Site selection: On the near side or a favorable polar region, ideally along a crater rim or in a shielded basin where solar energy is abundant and water ice is accessible. A terminator zone (the sunrise/sunset line) is popular for energy balance and dramatic lighting in visuals.
# - Core districts:
#   - Civic Core: Government buildings, courts, parliaments, ministries, and the central plaza. An elegant mix of brutalist and glass-domes designed to symbolize transparency and resilience.
#   - Research Arcology: A vertical cluster of laboratories, universities, and think tanks; public observatories and instrument stacks crown a high-rise tower.
#   - Spaceport and Industrial Crescent: The primary port for shipments from Earth and for lunar export. Workshops, fabrication plants, mining support facilities, and clean-room hubs.
#   - Residential Rings: Modular, climate-controlled living quarters with shared spaces, parks under transparent domes, and vertical farms.
#   - Cultural Crescent: Museums, libraries, theaters, lunar galleries, sacred and secular spaces, and public plazas that host concerts and festivals.
#   - Agricultural Domes: Hydroponic farms and algal farms producing food, oxygen, and bio-based materials.
#   - Energy Belt: A belt of solar arrays or concentrated solar farms; possibly supported by compact fusion micro-reactors as a backup.
#   - Observatory Boulevard: Large ground-based and space-based telescopes, plus citizen science centers inviting visitors and students.
#
# Technology and infrastructure (how it works)
# - Life support and atmosphere:
#   - Closed-loop air recycling with CO2 scrubbers, nitrogen-oxygen balance, and trace gas management.
#   - Water is extracted from ice deposits and recycled; methane and oxygen byproduct processing for fuel storage.
#   - Climate control inside habitats keeps Earth-like temperatures; external habitats are heavily insulated and pressure-hulled.
# - Habitat and architecture:
#   - A combination of inflatable modules, 3D-printed regolith shelters, and mined caverns reinforced with regolith and graphene composites.
#   - Radiant shielding against cosmic rays and micrometeoroids; dust mitigation systems prevent abrasion on surfaces and in machinery.
#   - Dome cities and crater-edge corridors connect districts with pressurized transit tunnels.
# - Energy:
#   - Primary solar energy captured by vast arrays on sunlit regolith or crater rims, with energy storage for the long lunar night.
#   - Backup microreactors or compact fusion units provide resilience during solar events or equipment downtimes.
# - Water and food:
#   - Water ice mined from permanently shadowed regions or extracted from lunar regolith; scrubbed and recycled.
#   - Hydroponics and algae farms supply fresh produce and oxygen; waste streams are repurposed into nutrients and bioplastics.
# - Transportation:
#   - Electric lunar rovers and rail-like vacuum tubes (mag-lev or airless-tube systems) ferry people and cargo across the city and between sites.
#   - A spaceport with shuttles to Earth, lunar orbit, and transfer points; emergency airlifts and medical shuttles for rapid response.
# - Communications:
#   - Laser/optical relay networks provide high-speed, low-latency comms with Earth and lunar outposts.
#   - Local mesh networks ensure resilient internal communications, crucial for emergencies.
# - Security and governance tech:
#   - Spaceborne satellites for surveillance and hazard detection; robust cyber-physical security against hacking and sabotage.
#   - Legal zones in the Civic Core and clear jurisdictional lines between lunar and Earth-based authorities.
#
# Society, culture, and daily life
# - Language and education:
#   - A common lunar standard (Lunar English or a bilingual Lunar Standard) with Earth languages taught in schools.
#   - Strong emphasis on STEM education, space ethics, planetary defense, and citizen science.
# - Daily life:
#   - The lunar day is 29.5 Earth days, so people work in shifts with artificial circadian rhythms, flexible hours, and communal rest days.
#   - Housing emphasizes comfort and community: shared terraces, community kitchens, and education spaces for families and students.
#   - Culture thrives through public art, lunar cinema, and a robust festival calendar aligned to solar events and historical milestones in lunar exploration.
# - Cuisine:
#   - Fresh produce from hydroponics, algae-based proteins, regolith-derived minerals (processed safely), and Earth-import flavors adapted to lunar life.
#
# Economy and major industries
# - Primary sectors:
#   - Lunar resource extraction: water ice, volatile compounds, and minerals.
#   - Energy production: solar farms with advanced storage; optional fusion micro-reactors.
#   - Manufacturing and microgravity fabrication: precision optics, semiconductor materials, pharmaceuticals, and high-precision components.
#   - Research and tourism: space sciences, observatories, citizen science programs, and guided lunar tours (crater rims, glassy plains, and historic landing sites).
# - Trade with Earth:
#   - Lunar goods (water-based fuels, rare minerals, high-precision components) and services (research, mining support, tourism).
#   - Earth–Moon governance agreements govern resource sharing, environmental standards, and security protocols.
#
# Key landmarks and iconic features
# - The Dome of Dawn: A luminous civic center that fills with light at sunrise, serving as a symbolic heart of governance.
# - The Spire Observatory: A tall lab and observation platform that doubles as a public science museum; combines telescopes with interactive displays.
# - The Salt Market: An open-air market plaza near the port where lunar and Earth goods mingle, featuring holographic vendor stalls and lunar-curated street food.
# - The Crater Edge Promenade: A pedestrian route along a crater rim with spectacular views, winded tunnels, and climate-controlled green spaces.
# - The Lunar Institute of Arts: A cultural hub housing theaters, galleries, and collaborative studios that blend Earth and Moon aesthetics.
#
# Governance and politics (building the backdrop)
# - System: A federated lunar government with a Lunar Assembly, an Executive Council, and regional lunar districts. Earth liaison offices exist to coordinate interplanetary policy.
# - Challenges: Resource competition, protection of water and energy rights, and maintaining unity among diverse lunar settlements. Periodic tensions may arise from migration surges, corporate influence, or resource scarcity, providing plot seeds or political intrigue.
# - Security posture: A civilian-led security service with civil liberties protected by law, augmented by technical protection against cyber threats and space hazards.
#
# Plot hooks, conflicts, and story ideas
# - A water ice discovery beneath the polar dome sparks a political crisis about ownership and exploitation rights.
# - A solar flare destroys part of the energy grid; a race against time to repair backups while the Moon’s night far outweighs the day.
# - Corporate influence and a graft scandal threaten the legitimacy of the Lunar Assembly; a whistleblower alliance uncovers a larger conspiracy.
# - A new arcology is inaugurated but reveals unexpected structural weaknesses in the shielding against micrometeoroids; a team must improvise a fix.
# - A diplomatic incident with Earth over a border dispute within the lunar territories tests interplanetary law and the survivability of Luna City’s institutions.
#
# If you want, I can tailor Luna City to a specific vibe:
# - Hard sci-fi realism: focus on physics, engineering constraints, and plausible technologies; more grounded governance and infrastructure.
# - Optimistic future-punk: brighter aesthetics, proactive people, and imaginative tech that blends utility and whimsy.
# - Mystery-adventure or political thriller: more intrigue, factions, and plot hooks centered on governance, espionage, or resource politics.
# - Mythic or fantasy-flavored: add cultural rites, lunar folklore, and magical realism elements that fit a lunar setting.
#
# Would you like me to adapt Luna City to a particular tone, time period, or tech level? If you’re building a world, tell me a few constraints (e.g., number of inhabitants, key industries, or the political setup), and I’ll generate a coherent, detailed version that fits your project.
