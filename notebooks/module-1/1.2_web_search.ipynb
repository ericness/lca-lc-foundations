# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(model="gpt-5-nano")

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke({"messages": [question]})

# %%
print(response["messages"][-1].content)
# Out:
# I don’t have real-time access to the web. My training data goes up to around late 2023 (the exact cutoff can vary by deployment). I can help with general knowledge and events up to then, but I may not know about things that happened after that unless you provide details or enable browsing in your environment. If you need the latest information, I can help you find current sources or summarize what’s known from reliable, up-to-date references.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()


@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the web for information"""

    return tavily_client.search(query)


web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.95334905,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.8755427,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.8488849,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie - Wikipedia',
#    'content': 'Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco, serving since',
#    'score': 0.82895297,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/profile--daniel-lurie',
#    'title': 'Daniel Lurie - SF.gov',
#    'content': "Chair, and Mayor of San Francisco. Disaster Council · Office of the Mayor. Mayor Daniel Lurie sworn in as the City's 46th mayor on Jan 8. See recent news. Learn",
#    'score': 0.8194462,
#    'raw_content': None}],
#  'response_time': 0.73,
#  'request_id': '51dbe748-8938-4383-81d4-145fc4169843'}

# %%
agent = create_agent(model="gpt-5-nano", tools=[web_search])

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke({"messages": [question]})

# %%
from pprint import pprint

pprint(response["messages"])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='d98a5de9-ff03-4146-bf06-95c74f48f19a'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 414, 'prompt_tokens': 133, 'total_tokens': 547, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7Turkpn2pAGs6o31CT1VzhtZvKrn', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c447e-7904-7682-8da3-0d80345dd892-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco 2026'}, 'id': 'call_dXwlV5v6y4z9pWVINa8LUfBy', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 414, 'total_tokens': 547, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco 2026", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor - SF.gov", "content": "Daniel Lurie is the 46th Mayor of the City and County of San Francisco ... January 28, 2026 · Mayor Lurie Outlines Preparations to Keep San Franciscans and", "score": 0.9959927, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco - Wikipedia", "content": "Mayor of San Francisco ; Flag of San Francisco. Incumbent Daniel Lurie. since January 8, 2025. Government of San Francisco ; Flag of San Francisco. Incumbent", "score": 0.99469805, "raw_content": null}, {"url": "https://www.nytimes.com/2026/02/03/us/san-francisco-mayor-daniel-lurie.html", "title": "San Francisco Mayor Daniel Lurie Focuses on Small City Changes ...", "content": "Daniel Lurie has made small changes instead of addressing national tensions, and his approval ratings have been strong.", "score": 0.9941801, "raw_content": null}, {"url": "https://www.facebook.com/SF/videos/mayor-daniel-luries-state-of-the-city-address-2026/1586108175969776/", "title": "Join San Francisco Mayor Daniel Lurie for his State of the City ...", "content": "Join San Francisco Mayor Daniel Lurie for his State of the City Address 2026. SS Jeremiah O\'Brien, National Liberty Ship Memor.", "score": 0.992062, "raw_content": null}, {"url": "https://www.sfchronicle.com/sf/article/daniel-lurie-lays-out-sf-road-map-in-state-of-city-21286425.php", "title": "Daniel Lurie lays out 2026 road map for S.F.: \'I will not back down\'", "content": "Mayor Daniel Lurie focused on trying to make San Francisco more affordable and delivering structural change at City Hall that makes the", "score": 0.9766692, "raw_content": null}], "response_time": 1.14, "request_id": "88b34e55-886f-48bd-977f-4fa9d08b4eba"}', name='web_search', id='3f0835af-27a5-4249-a467-9bcbe694650f', tool_call_id='call_dXwlV5v6y4z9pWVINa8LUfBy'),
#  AIMessage(content='Daniel Lurie is the current mayor of San Francisco. He is the city’s 46th mayor, taking office in January 2025.\n\nFor official confirmation, you can check the Office of the Mayor page on SF.gov. Sources also note his incumbency (e.g., Wikipedia, NYTimes).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 582, 'prompt_tokens': 719, 'total_tokens': 1301, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D7TuxswctD7uTHUR0JtTL4oseVXDQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c447e-9119-7c30-8ac2-7de4d974c5ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 719, 'output_tokens': 582, 'total_tokens': 1301, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
